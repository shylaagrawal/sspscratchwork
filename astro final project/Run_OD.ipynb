# %%
# Shyla Agrawal 
# 7/13/26
# Running the OD's

import agrawalOD1
import agrawalOD2
import agrawalOD3
import agrawalOD4
import agrawalOD5
import agrawalUncertainty

from importlib import reload
reload(agrawalOD1)
reload(agrawalOD2)
reload(agrawalOD3)
reload(agrawalOD4)
reload(agrawalOD5)
reload(agrawalUncertainty)
# Out:
# <module 'agrawalUncertainty' from '/workspaces/sspscratchwork/astro final project/agrawalUncertainty.py'>

# %%
agrawalOD1.main()
# Out:
# Calculated: -0.341081, 0.228006, 0.873642
# Expected:   -0.341081, 0.228006, 0.873642

# %%
agrawalOD2.main()
# Out:
# a:       1.056800           expected: 1.056800
# e:       0.344233           expected: 0.344233
# i:       25.155252          expected: 25.155252
# Omega:   236.237981         expected: 236.237981
# omega:   255.504615         expected: 255.504615
# M:       140.419457         expected: 140.419457

# %%
agrawalOD3.main()
# Out:
# Predicted RA: 271.3910426100967
# Expected RA: 271.38604166666664
# RA difference: 18.00339634817192 arcsec
#
# Predicted Dec: 35.64818717333999
# Expected Dec: 35.64658333333333
# Dec difference: 5.773824023972907 arcsec

# %%
agrawalOD4.main()
# Out:
# Computed f: 0.995000 Computed g: 0.099833
# Expected f: 0.995 Expected g: 0.099833
#
# Computed f: 0.997699 Computed g: 0.499602
# Expected f: 0.997699 Expected g: 0.499602
#
# Computed f: 0.982449 Computed g: -0.324270
# Expected f: 0.982449 Expected g: -0.32427
#
# Computed f: 0.994993 Computed g: 0.099833
# Expected f: 0.994993 Expected g: 0.099833
#
# Computed f: 0.997695 Computed g: 0.499624
# Expected f: 0.997695 Expected g: 0.499624
#
# Computed f: 0.982325 Computed g: -0.324004
# Expected f: 0.982325 Expected g: -0.324004

# %%
agrawalOD5.main()
# Out:
# Asteroid: 2002 QF15
#
# Vector Error
# Position error: 6.981388174597522e-05 AU
# Velocity error: 1.8162635718423895e-06 AU/day
#
# Orbital Element Error
# a:  1.056841527969094        | JPL:  1.056800056  | Difference:  0.00392429664045995 %
# e:  0.3442731260281259       | JPL:  0.344233109  | Difference:  0.011624979433891064 %
# i:  25.157918685555597       | JPL:  25.15525144  | Difference:  0.010603136136237538 %
# Omega:  236.242764910038    | JPL:  236.2379806  | Difference:  0.0020252078119986933 %
# omega:  255.50785580416414   | JPL:  255.5046146  | Difference:  0.001268550147015918 %
# M:  140.39950782320201       | JPL:  140.4194574  | Difference:  0.014207131381483346 %
# ---------------------------------------------------------------------------------------------
# Asteroid: 2003 UD8
#
# Vector Error
# Position error: 0.00018921656934064613 AU
# Velocity error: 2.5472552066157774e-06 AU/day
#
# Orbital Element Error
# ...

# %%
agrawalUncertainty.main()
# Out:
# /workspaces/sspscratchwork/astro final project/agrawalUncertainty.py:87: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# # shyla is the best :)
