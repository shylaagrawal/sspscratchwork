# %%
# Shyla Agrawal 
# 7/13/26
# Running the OD's

import agrawalOD1
import agrawalOD2
import agrawalOD3
import agrawalOD4
import agrawalOD5

from importlib import reload
reload(agrawalOD1)
reload(agrawalOD2)
reload(agrawalOD3)
reload(agrawalOD4)
reload(agrawalOD5)
# Out:
# <module 'agrawalOD5' from '/workspaces/sspscratchwork/astro final project/agrawalOD5.py'>

# %%
agrawalOD1.main()
# Out:
# Calculated: -0.341081, 0.228006, 0.873642
# Expected:   -0.341081, 0.228006, 0.873642

# %%
agrawalOD2.main()
# Out:
# a:       1.056800           expected: 1.056800
# e:       0.344233           expected: 0.344233
# i:       25.155252          expected: 25.155252
# Omega:   236.237981         expected: 236.237981
# omega:   255.504615         expected: 255.504615
# M:       140.419457         expected: 140.419457

# %%
agrawalOD3.main()
# Out:
# Predicted RA: 271.3865753976869
# Expected RA: 271.38604166666664
# RA difference: 1.9214316729176062 arcsec
#
# Predicted Dec: 35.64959154888476
# Expected Dec: 35.64658333333333
# Dec difference: 10.829575985130191 arcsec

# %%
agrawalOD4.main()
# Out:
# Computed f: 0.995000 Computed g: 0.099833
# Expected f: 0.995 Expected g: 0.099833
#
# Computed f: 0.997699 Computed g: 0.499602
# Expected f: 0.997699 Expected g: 0.499602
#
# Computed f: 0.982449 Computed g: -0.324270
# Expected f: 0.982449 Expected g: -0.32427
#
# Computed f: 0.994993 Computed g: 0.099833
# Expected f: 0.994993 Expected g: 0.099833
#
# Computed f: 0.997695 Computed g: 0.499624
# Expected f: 0.997695 Expected g: 0.499624
#
# Computed f: 0.982325 Computed g: -0.324004
# Expected f: 0.982325 Expected g: -0.324004

# %%
agrawalOD5.main()
# Out:
# Asteroid: 2002 QF15
#
# Position Vector (AU)
# [ 0.39702595 -1.31288485 -0.05169292]
#
# Velocity Vector (AU/day)
# [0.01139867 0.00096509 0.00450772]
#
# Vector Error
# Position error: 0.5337121208816844 AU
# Velocity error: 0.0018743532412139152 AU/day
#
#  Orbital Elements Compared to JPL
# a:  1.0568415279690941      | JPL:  1.056800056  | Difference:  0.0039242966404809615 %
# e:  0.34427312602812615     | JPL:  0.344233109  | Difference:  0.011624979433971692 %
# i:  22.419065454572365       | JPL:  25.15525144  | Difference:  10.877195928468268 %
# Omega:  292.06706370831756  | JPL:  236.2379806  | Difference:  23.63256025408032 %
# omega:  195.38639629685636  | JPL:  255.5046146  | Difference:  23.529210381292128 %
# M:  140.39950782320184      | JPL:  140.4194574  | Difference:  0.014207131381604787 %
# ---------------------------------------------------------------------------------------------
# Asteroid: 2003 UD8
#
# Position Vector (AU)
# ...

# %% [markdown]
# # shyla is the best :)
