# %%
# Shyla Agrawal 
# 7/13/26
# Running the OD's

import agrawalOD1
import agrawalOD2
import agrawalOD3

from importlib import reload
reload(agrawalOD1)
reload(agrawalOD2)
reload(agrawalOD3)
# Out:
# <module 'agrawalOD3' from '/workspaces/sspscratchwork/astro final project/agrawalOD3.py'>

# %%
agrawalOD1.main()
# Out:
# -0.341081, 0.228006, 0.873642

# %%
agrawalOD2.main()
# Out:
# a:       158095038.104285       expected: 158095038.088637
# e:       0.344233               expected: 0.344233
# i:       25.155252              expected: 25.155252
# Omega:   236.237981             expected: 236.237981
# omega:   255.504615             expected: 255.504615
# M:       140.419457             expected: 140.419457

# %%
agrawalOD3.main()
# Out:
# Predicted RA: 271.3910426100967
# Expected RA: 271.38604166666664
#
# Predicted Dec: 35.64818717333999
# Expected Dec: 35.64658333333333
