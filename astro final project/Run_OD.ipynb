# %%
# Shyla Agrawal 
# 7/13/26
# Running the OD's

import agrawalOD1
import agrawalOD2
import agrawalOD3
import agrawalOD4
import agrawalOD5
import agrawalMonteCarlos

from importlib import reload
reload(agrawalOD1)
reload(agrawalOD2)
reload(agrawalOD3)
reload(agrawalOD4)
reload(agrawalOD5)
reload(agrawalMonteCarlos)
# Out:
# <module 'agrawalMonteCarlos' from '/workspaces/sspscratchwork/astro final project/agrawalMonteCarlos.py'>

# %%
agrawalOD1.main()
# Out:
# Calculated: -0.341081, 0.228006, 0.873642
# Expected:   -0.341081, 0.228006, 0.873642

# %%
agrawalOD2.main()
# Out:
# a:       1.056800           expected: 1.056800
# e:       0.344233           expected: 0.344233
# i:       25.155252          expected: 25.155252
# Omega:   236.237981         expected: 236.237981
# omega:   255.504615         expected: 255.504615
# M:       140.419457         expected: 140.419457

# %%
agrawalOD3.main()
# Out:
# Predicted RA: 271.3910426100967
# Expected RA: 271.38604166666664
# RA difference: 18.00339634817192 arcsec
#
# Predicted Dec: 35.64818717333999
# Expected Dec: 35.64658333333333
# Dec difference: 5.773824023972907 arcsec

# %%
agrawalOD4.main()
# Out:
# Computed f: 0.995000 Computed g: 0.099833
# Expected f: 0.995 Expected g: 0.099833
#
# Computed f: 0.997699 Computed g: 0.499602
# Expected f: 0.997699 Expected g: 0.499602
#
# Computed f: 0.982449 Computed g: -0.324270
# Expected f: 0.982449 Expected g: -0.32427
#
# Computed f: 0.994993 Computed g: 0.099833
# Expected f: 0.994993 Expected g: 0.099833
#
# Computed f: 0.997695 Computed g: 0.499624
# Expected f: 0.997695 Expected g: 0.499624
#
# Computed f: 0.982325 Computed g: -0.324004
# Expected f: 0.982325 Expected g: -0.324004

# %%
agrawalOD5.main()
# Out:
# Asteroid: 4451 Grieve
#
# Orbital Element Error
# a:  2.589789627649646        | JPL:  2.604925635590923  | Difference:  0.5810533603905905 %
# e:  0.3937254926781235       | JPL:  0.3833326434498465  | Difference:  2.711182938855752 %
# i:  27.114248762366955       | JPL:  27.79781152014452  | Difference:  2.4590524231815913 %
# Omega:  217.91733082817487    | JPL:  219.3761119603363  | Difference:  0.6649680856889152 %
# omega:  113.7078673552024   | JPL:  110.2360012018431  | Difference:  3.14948484660858 %
# M:  337.9461417253175       | JPL:  336.8848198493519  | Difference:  0.31503998204495437 %
# ---------------------------------------------------------------------------------------------

# %%
agrawalMonteCarlos.main()
# Out:
# Monte Carlo Results:
# ----------------------------------------
# a (AU)      :     2.589801 +/-   0.000480
# e           :     0.393725 +/-   0.000059
# i (deg)     :    27.114419 +/-   0.007403
# Omega (deg) :   217.917596 +/-   0.012359
# omega (deg) :   113.707315 +/-   0.026708
# M (deg)     :   337.946294 +/-   0.006228
# ----------------------------------------

# %% [markdown]
# # shyla is the best :)
