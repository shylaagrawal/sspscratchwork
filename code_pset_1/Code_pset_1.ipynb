# %%
from importlib import reload

# %%
# Run tests for "approx_equals.py"

import approx_equals
reload(approx_equals)

approx_equals.main()
# Out:
# TESTING: is_close_absolute
# All tests passed!
# TESTING: is_close_relative
# All tests passed!
# TESTING: is_close
# All tests passed!

# %%
# Run tests for "vectors.py"

import vectors
reload(vectors)

vectors.main()
# Out:
# TESTING: vector_magnitude
#
# Actual:   1.0
# Expected: 1
#
# Actual:   2.0
# Expected: 2
#
# Actual:   14.142135623730951
# Expected: 14.142136
#
# TESTING: dot_product
#
# Actual:   0
# Expected: 0
#
# Actual:   6
# Expected: 6
#
# Actual:   89
# Expected: 89
#
# Actual:   0
# Expected: 0
#
# Actual:   18
# Expected: 18
#
# TESTING: cross_product
#
# Actual:   [0, 0, 1]
# Expected: [0, 0, 1]
#
# Actual:   [-2, 2, -1]
# Expected: [-2, 2, -1]
#
# Actual:   [-47, -5, 8]
# Expected: [-47, -5, 8]
#
# Actual:   [4, 0, -4]
# Expected: [4, 0, -4]

# %%
# Run tests for "list_sort.py"

import list_sort
reload(list_sort)

list_sort.main()
# Out:
# TESTING: get_minimum
#
# Actual:   1
# Expected: 1
#
# Actual:   -1
# Expected: -1
#
# Actual:   -10
# Expected: -10
#
# Actual:   -324
# Expected: -324
#
# TESTING: remove_minimum
#
# Actual:   [3, 4, 5, 6, 6, 7]
# Expected: [3, 4, 5, 6, 6, 7]
#
# Actual:   [4]
# c
#
# Actual:   [2, 0, 5, 6]
# Expected: [2, 0, 5, 6]
#
# Actual:   [3, 4, 5]
# Expected: [3, 4, 5]
#
# TESTING: sort_list
#
# Actual:   [0, 0, 1]
# Expected: [0, 0, 1]
#
# Actual:   [3, 7, 8]
# Expected: [3, 7, 8]
#
# Actual:   [0, 5, 8]
# Expected: [0, 5, 8]
#
# Actual:   [-2, 0, 2]
# Expected: [-2, 0, 2]
